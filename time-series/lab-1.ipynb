# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/AirPassenger.csv')
df
# Out:
#     Year-Month  Pax
# 0     1949-Jan  112
# 1     1949-Feb  118
# 2     1949-Mar  132
# 3     1949-Apr  129
# 4     1949-May  121
# ..         ...  ...
# 139   1960-Aug  606
# 140   1960-Sep  508
# 141   1960-Oct  461
# 142   1960-Nov  390
# 143   1960-Dec  432
#
# [144 rows x 2 columns]

# %%
df.dtypes
# Out:
# Year-Month    object
# Pax            int64
# dtype: object

# %%
df1 = pd.read_csv('data/AirPassenger.csv', parse_dates = ['Year-Month'])
df1
# Out:
# C:\Users\Surya\AppData\Local\Temp\ipykernel_25224\991022512.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1 = pd.read_csv('data/AirPassenger.csv', parse_dates = ['Year-Month'])
#     Year-Month  Pax
# 0   1949-01-01  112
# 1   1949-02-01  118
# 2   1949-03-01  132
# 3   1949-04-01  129
# 4   1949-05-01  121
# ..         ...  ...
# 139 1960-08-01  606
# 140 1960-09-01  508
# 141 1960-10-01  461
# 142 1960-11-01  390
# 143 1960-12-01  432
#
# [144 rows x 2 columns]

# %%
df1.dtypes
# Out:
# Year-Month    datetime64[ns]
# Pax                    int64
# dtype: object

# %%
df1 = pd.read_csv('data/AirPassenger.csv', parse_dates=['Year-Month'], index_col=['Year-Month'])
df1
# Out:
# C:\Users\Surya\AppData\Local\Temp\ipykernel_25224\98532264.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1 = pd.read_csv('data/AirPassenger.csv', parse_dates=['Year-Month'], index_col=['Year-Month'])
#             Pax
# Year-Month
# 1949-01-01  112
# 1949-02-01  118
# 1949-03-01  132
# 1949-04-01  129
# 1949-05-01  121
# ...         ...
# 1960-08-01  606
# 1960-09-01  508
# 1960-10-01  461
# 1960-11-01  390
# 1960-12-01  432
#
# [144 rows x 1 columns]

# %%
df1['1960-08-01':'1962-08-01']
# Out:
#             Pax
# Year-Month
# 1960-08-01  606
# 1960-09-01  508
# 1960-10-01  461
# 1960-11-01  390
# 1960-12-01  432

# %%
df1.loc['1960-08-01']
# Out:
# Pax    606
# Name: 1960-08-01 00:00:00, dtype: int64

# %%
df1.plot()
plt.show()

# %%
df1.plot(figsize=(20, 6))
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

df_seasonal_decompose = seasonal_decompose(df1, model='additive', period=12)
df_seasonal_decompose.plot()
plt.show()

# %%
df_seasonal_decompose = seasonal_decompose(df1, model='multiplicative', period=12)
df_seasonal_decompose.plot()
plt.show()

# %%
df1 = pd.read_csv('data/daily-total-female-births.csv', parse_dates=['Date'], index_col=['Date'])
df1
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %%
df1.plot(figsize=(12,6))
plt.show()

# %%
df1_seasonal_decompose = seasonal_decompose(df1, model='additive', period=12)
df1_seasonal_decompose.plot()
plt.show()

# %%
df1_seasonal_decompose = seasonal_decompose(df1, model='multiplicative', period=12)
df1_seasonal_decompose.plot()
plt.show()
